# %%
pip install pandas nltk textblob scikit-learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob

# %%
column_names  = ['text', 'sentiment']
df = pd.read_csv('https://raw.githubusercontent.com/sanfla/Project/main/TugasAILab/olahraga_training%20-%20Sheet1.csv', header=None, names=column_names)
df
# Out:
#                                                   text               sentiment
# 0                                                 text               sentiment
# 1    Saat ini berat badanku sangat tinggi. aku mera...  Menurunkan Berat Badan
# 2                  Badan ku terlalu besar berat gendut  Menurunkan Berat Badan
# 3    Aku ingin mencari tips dan trik untuk menurunk...  Menurunkan Berat Badan
# 4    Berat badanku sudah mencapai angka yang tidak ...  Menurunkan Berat Badan
# ..                                                 ...                     ...
# 353  Apakah ada olahraga yang dapat membantu mening...                    Diet
# 354  Bagaimana memilih jenis latihan yang tidak han...                    Diet
# 355  Apa rekomendasi untuk latihan yang dapat dilak...                    Diet
# 356  Bagaimana cara membangun rutinitas olahraga ya...                    Diet
# 357  Apakah ada olahraga yang dapat memberikan efek...                    Diet
#
# [358 rows x 2 columns]

# %% [markdown]
# Explorasi Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Tampilkan lima baris pertama dataset
print("Lima Baris Pertama Dataset:")
print(df.head())
plt.show()
# Out:
# Lima Baris Pertama Dataset:
#                                                 text               sentiment
# 0                                               text               sentiment
# 1  Saat ini berat badanku sangat tinggi. aku mera...  Menurunkan Berat Badan
# 2                Badan ku terlalu besar berat gendut  Menurunkan Berat Badan
# 3  Aku ingin mencari tips dan trik untuk menurunk...  Menurunkan Berat Badan
# 4  Berat badanku sudah mencapai angka yang tidak ...  Menurunkan Berat Badan

# %%
#Hapus baris yang ada null
df = df.dropna(axis=0)

# %% [markdown]
# Data Proccecing

# %%
#Memasukan Data validasi
column_names  = ['text', 'sentiment']
df_validation = pd.read_csv('https://raw.githubusercontent.com/sanfla/Project/main/TugasAILab/olahraga_validation%20-%20Sheet1.csv', header=None, names=column_names)

#Hapus baris yang ada null
df_validation = df_validation.dropna(axis=0)
df_validation
# Out:
#                                                   text               sentiment
# 0                                                 text               sentiment
# 1    Apakah ada program diet tertentu yang dapat me...  Menurunkan Berat Badan
# 2    Aku mencoba berbagai cara untuk menurunkan ber...  Menurunkan Berat Badan
# 3    Apa saja tips untuk mengatasi nafsu makan berl...  Menurunkan Berat Badan
# 4    Aku ingin mencapai target berat badan yang leb...  Menurunkan Berat Badan
# ..                                                 ...                     ...
# 208  Apakah terdapat latihan yang dapat membantu me...                    Diet
# 209  Bagaimana cara membangun kebiasaan olahraga ya...                    Diet
# 210  Apa rekomendasi untuk latihan ringan yang dapa...                    Diet
# 211  Bagaimana cara menjaga kebugaran tubuh sambil ...                    Diet
# 212  Apakah terdapat latihan yang dapat membantu me...                    Diet
#
# [213 rows x 2 columns]

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# Preprocessing Teks
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    words = word_tokenize(text)
    filtered_words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    return ' '.join(filtered_words)

df['clean_text'] = df['text'].apply(preprocess_text)
df_validation['clean_text'] = df_validation['text'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#Pembagian dataset
X_train, X_test, y_train, y_test = train_test_split(df['clean_text'], df['text'], test_size=0.2, random_state=42)

# %%
# Menggunakan dataset yang telah dibagi dari file validasi
X_train, y_train = df['clean_text'], df['sentiment']
X_test, y_test = df_validation['clean_text'], df_validation['sentiment']

# %%
# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# Model Naive Bayes
nb_model = MultinomialNB()
nb_model.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# Model

# %%
# Evaluasi Model
y_pred = nb_model.predict(X_test_tfidf)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.9671361502347418
# Classification Report:
#                          precision    recall  f1-score   support
#
#  Menurunkan Berat Badan       0.00      0.00      0.00         2
#                    Diet       1.00      1.00      1.00        30
#    Menaikan Berat Badan       0.97      1.00      0.98        30
#     Menaikan Massa Otot       1.00      1.00      1.00        30
#  Menurunkan Berat Badan       0.94      0.97      0.95        30
#                    Umum       0.97      0.93      0.95        30
#               Usia Muda       0.97      1.00      0.98        30
#                Usia Tua       0.94      0.97      0.95        30
#               sentiment       0.00      0.00      0.00         1
#
#                accuracy                           0.97       213
#               macro avg       0.75      0.76      0.76       213
#            weighted avg       0.95      0.97      0.96       213
# ...

# %%
# Fungsi untuk prediksi sentimen dengan empat kelas
def predict_sentiment(text):
    cleaned_text = preprocess_text(text)
    vectorized_text = tfidf_vectorizer.transform([cleaned_text])
    prediction = nb_model.predict(vectorized_text)[0]

    return prediction

# %%
# Uji Model dengan Input Pengguna
user_input = input("Masukkan teks untuk diuji sentimennya: ")
prediction_output = predict_sentiment(user_input)
print(f'Prediksi Sentimen: {prediction_output}')

# %%
df_response = pd.read_csv("https://raw.githubusercontent.com/sanfla/Project/main/TugasAILab/response_olahraga%20-%20Sheet1%20(1).csv")
df_response
# Out:
#                  sentiment                                           response
# 0   Menurunkan Berat Badan  Cobalah untuk menyertakan olahraga kardio sepe...
# 1   Menurunkan Berat Badan  Anda bisa mencoba aktivitas yang menyenangkan ...
# 2   Menurunkan Berat Badan  Jika tertarik pada variasi pertimbangkan yoga ...
# 3   Menurunkan Berat Badan  Jika mencari efisiensi pertimbangkan latihan H...
# 4   Menurunkan Berat Badan  Anda bisa mencoba latihan kekuatan seperti ang...
# 5     Menaikan Berat Badan  Anda bisa pertimbangkan untuk menyertakan akti...
# 6     Menaikan Berat Badan  Jika tujuanmu menaikkan berat badan coba untuk...
# 7     Menaikan Berat Badan  Cobalah untuk meningkatkan intensitas latihan ...
# 8     Menaikan Berat Badan  Jika ingin mencoba sesuatu yang berbeda pertim...
# 9     Menaikan Berat Badan  Cobalah untuk fokus pada latihan kekuatan sepe...
# 10     Menaikan Massa Otot  Anda bisa pertimbangkan untuk memasukkan latih...
# ...

# %%
def get_random_response(sentiment):
    relevant_responses = df_response[df_response['sentiment'] == sentiment]['response']
    if not relevant_responses.empty:
        return np.random.choice(relevant_responses)
    else:
        return "Maaf, kami belum dapat merekomendasikan makanan kepada anda."

# %%
user_input = input("Masukkan teks untuk diuji sentimennya: ")
prediction_output = predict_sentiment(user_input)
random_response = get_random_response(prediction_output)
print(f"Prediksi Sentimen: {prediction_output}")
print(f"Respons: {random_response}")
# Out:
# Masukkan teks untuk diuji sentimennya: naikin berat badan
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-860d4e6fa2ac> in <cell line: 2>()
#       1 user_input = input("Masukkan teks untuk diuji sentimennya: ")
# ----> 2 prediction_output = predict_sentiment(user_input)
#       3 random_response = get_random_response(prediction_output)
#       4 print(f"Prediksi Sentimen: {prediction_output}")
#       5 print(f"Respons: {random_response}")
#
# NameError: name 'predict_sentiment' is not defined
