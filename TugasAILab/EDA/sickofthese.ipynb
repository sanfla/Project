# %%
pip install pandas nltk textblob scikit-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob

# %%
column_names  = ['text', 'sentiment']
df = pd.read_csv('https://raw.githubusercontent.com/adeikmalm/sedangsakitnew/main/sedangsakit_training.csv', header=None, names=column_names)
df
# Out:
#                                                   text     sentiment
# 0                                                 text     sentiment
# 1                Perutku sering terasa panas dan nyeri  asam lambung
# 2    Makanan pedas selalu membuat perutku tidak nyaman  asam lambung
# 3    Terlalu banyak makan malam membuat perutku ter...  asam lambung
# 4    Minum kopi saat perut kosong selalu mengakibat...  asam lambung
# ..                                                 ...           ...
# 496                         Emosiku sulit dikendalikan  darah tinggi
# 497                                Badanku mudah lelah  darah tinggi
# 498              Setelah kejadian mengganggu pikiranku  darah tinggi
# 499                              Emosiku sering meluap  darah tinggi
# 500                                Badanku mudah lemas  darah tinggi
#
# [501 rows x 2 columns]

# %%
df["sentiment"].unique()
# Out:
# array(['sentiment', 'asam lambung', 'demam', 'flu', 'sakit perut',
#        'pusing', 'sakit mata', 'diabetes', 'pilek', 'masuk angin',
#        'darah tinggi'], dtype=object)

# %%
aimport pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Tampilkan lima baris pertama dataset
print("Lima Baris Pertama Dataset:")
print(df.head())
plt.show()
# Out:
# Lima Baris Pertama Dataset:
#                                                 text       sentiment  \
# 0              Perutku sering terasa panas dan nyeri   asam lambung.
# 1  Makanan pedas selalu membuat perutku tidak nyaman   asam lambung.
# 2  Terlalu banyak makan malam membuat perutku ter...   asam lambung.
# 3  Minum kopi saat perut kosong selalu mengakibat...   asam lambung.
# 4  Suka ngemil sebelum tidur membuat perutku tera...   asam lambung.
#
#                                           clean_text
# 0              perutku sering terasa panas dan nyeri
# 1  makanan pedas selalu membuat perutku tidak nyaman
# 2  terlalu banyak makan malam membuat perutku ter...
# 3  minum kopi saat perut kosong selalu mengakibat...
# 4  suka ngemil sebelum tidur membuat perutku tera...

# %%
#Hapus baris yang ada null
df = df.dropna(axis=0)

# %%
#Memasukan Data validasi
column_names  = ['text', 'sentiment']
df_validation = pd.read_csv('https://raw.githubusercontent.com/adeikmalm/sedangsakitnew/main/sedangsakit_validation.csv', header=None, names=column_names)

#Hapus baris yang ada null
df_validation = df_validation.dropna(axis=0)
df_validation
# Out:
#                                                  text      sentiment
# 0   Saya kesulitan tidur. Apa yang bisa saya lakuk...         stress
# 1   Saya merasa stress di tempat kerja. Bagaimana ...         stress
# 2   Saya sering lupa hal-hal kecil. Adakah tips un...         stress
# 3   Saya ingin menjaga kesehatan jantung saya. Apa...         stress
# 5   Saya merasa cepat lelah saat beraktivitas fisi...          demam
# ..                                                ...            ...
# 95  Bagaimana cara mengatasi gangguan tidur akibat...         stress
# 96  Saya ingin meningkatkan kesehatan tulang. Apa ...   darah tinggi
# 97  Apa manfaat tidur telanjang bagi kesehatan kulit?    masuk angin
# 98  Bagaimana cara mengatasi rasa letih dan kurang...    sakit perut
# 99  Saya ingin memulai program latihan HIIT. Bagai...   darah tinggi
#
# [96 rows x 2 columns]

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# Preprocessing Teks
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    words = word_tokenize(text)
    filtered_words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    return ' '.join(filtered_words)

df['clean_text'] = df['text'].apply(preprocess_text)
df_validation['clean_text'] = df_validation['text'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Pembagian dataset
X_train, X_test, y_train, y_test = train_test_split(df['clean_text'], df['text'], test_size=0.2, random_state=42)

# %%
# Menggunakan dataset yang telah dibagi dari file validasi
X_train, y_train = df['clean_text'], df['sentiment']
X_test, y_test = df_validation['clean_text'], df_validation['sentiment']

# %%
# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# Model Naive Bayes
nb_model = MultinomialNB()
nb_model.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
# Evaluasi Model
y_pred = nb_model.predict(X_test_tfidf)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.0
# Classification Report:
#                 precision    recall  f1-score   support
#
#          demam       0.00      0.00      0.00       1.0
#   asam lambung       0.00      0.00      0.00       6.0
#  asam lambung.       0.00      0.00      0.00       0.0
#   darah tinggi       0.00      0.00      0.00      15.0
#  darah tinggi.       0.00      0.00      0.00       0.0
#   darha tinggi       0.00      0.00      0.00       1.0
#          demam       0.00      0.00      0.00       1.0
#         demam.       0.00      0.00      0.00       0.0
#       diabetes       0.00      0.00      0.00      17.0
#      diabetes.       0.00      0.00      0.00       0.0
#            flu       0.00      0.00      0.00       5.0
#           flu.       0.00      0.00      0.00       0.0
#        lambung       0.00      0.00      0.00       1.0
#    masuk angin       0.00      0.00      0.00       5.0
#   masuk angin.       0.00      0.00      0.00       0.0
#         pilek.       0.00      0.00      0.00       0.0
#         pusing       0.00      0.00      0.00      10.0
#        pusing.       0.00      0.00      0.00       0.0
#     sakit mata       0.00      0.00      0.00       3.0
#    sakit mata.       0.00      0.00      0.00       0.0
#    sakit perut       0.00      0.00      0.00      10.0
#   sakit perut.       0.00      0.00      0.00       0.0
#         stress       0.00      0.00      0.00      20.0
#   darah tinggi       0.00      0.00      0.00       1.0
#
#       accuracy                           0.00      96.0
#      macro avg       0.00      0.00      0.00      96.0
#   weighted avg       0.00      0.00      0.00      96.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Fungsi untuk prediksi sentimen dengan empat kelas
def predict_sentiment(text):
    cleaned_text = preprocess_text(text)
    vectorized_text = tfidf_vectorizer.transform([cleaned_text])
    prediction = nb_model.predict(vectorized_text)[0]

    return prediction

# %%
# Uji Model dengan Input Pengguna
user_input = input("Masukkan teks untuk diuji sentimennya: ")
prediction_output = predict_sentiment(user_input)
print(f'Prediksi Sentimen: {prediction_output}')
# Out:
# Masukkan teks untuk diuji sentimennya: tes
# Prediksi Sentimen:  darah tinggi.

# %%
df_response = pd.read_csv("https://raw.githubusercontent.com/adeikmalm/sedangsakitnew/main/response_sedangsakit.csv")
df_response
# Out:
#         sentimen                                           response
# 0   asam lambung   Suka makan terlalu cepat membuat perutku tera...
# 1   asam lambung   Minum minuman bersoda selalu menyebabkan peru...
# 2   asam lambung   Sering mengonsumsi makanan tinggi asam selalu...
# 3   asam lambung   Malas sarapan selalu membuat perutku tidak st...
# 4   asam lambung   Makan makanan berat di malam hari selalu meng...
# 5          demam   Aku merasa kedinginan dan tubuhku menggigil s...
# 6          demam   Aku baru saja menyelesaikan shift malam. Past...
# 7          demam   Aku merasa pusing dan tubuhku terasa panas de...
# 8          demam   Aku merasa tidak enak badan setelah terlalu l...
# 9          demam   Baru saja berinteraksi dengan seseorang yang ...
# 10           flu   Hidungku tersumbat dan badanku terasa lemas. ...
# 11           flu   Aku sering merasa tidak enak badan dan bersin...
# 12           flu   Aku merasa demam dan hidungku meler. Minum ai...
# 13           flu   Setelah bersin aku merasa tubuhku panas dan p...
# 14           flu   Aku merasa tenggorokanku sakit dan badanku te...
# 15   sakit perut   Setelah makan makanan pedas sekarang perutku ...
# 16   sakit perut   Aku habis makan makanan berbumbu pedas perutk...
# 17   sakit perut   Perutku terasa tidak nyaman dan mules setelah...
# 18   sakit perut   Aku merasa sakit perut setelah mengonsumsi hi...
# 19   sakit perut   Setelah makan makanan berbumbu pedas sekarang...
# 20        pusing   Setelah menghadapi masalah yang kompleks seka...
# 21        pusing   Aku merasa tidak enak badan dan kepalaku berd...
# 22        pusing   Kepalaku sakit dan aku merasa stres dengan tu...
# 23        pusing   Baru saja mengalami kelelahan fisik sekarang ...
# 24    sakit mata   Setelah membaca buku dalam waktu yang lama.  ...
# 25    sakit mata   Mataku tidak nyaman setelah terpapar debu dan...
# 26    sakit mata   Aku mengalami gangguan penglihatan dan mataku...
# 27    sakit mata   Setelah menatap layar ponsel dalam waktu yang...
# 28    sakit mata   Aku merasa tidak enak badan dan mataku lelah....
# 29      diabetes   Setelah menyantap makanan tinggi gula sekaran...
# 30      diabetes   Aku sering minum minuman bersoda.  Pertimbang...
# 31      diabetes   Aku mudah merasa haus karena kebiasaan minum ...
# 32      diabetes   Setelah makan es krim sekarang aku mudah haus...
# 33      diabetes   Aku suka mengonsumsi permen karet manis. bata...
# 34         pilek   Setelah minum minuman es coklat.  hindari men...
# 35         pilek   Aku terpapar udara dingin di pantai.  Kenakan...
# 36         pilek   Aku suka minum es kacang hijau. Minum es kaca...
# 37         pilek   Setelah minum minuman es sirup. Minumlah minu...
# 38         pilek   Aku terkena embun saat jogging pagi. Setelah ...
# 39   masuk angin   Aku sering minum minuman dingin. Minum minuma...
# 40   masuk angin   Aku muntah dan badanku kedinginan.  Istirahat...
# 41   masuk angin   Badanku terasa lelah dan mual.  Istirahatlah ...
# 42   masuk angin   Setelah beraktivitas di udara dingin. Kenakan...
# 43   masuk angin   Aku muntah dan sering bersendawa setelah mand...
# 44  darah tinggi   Emosiku cenderung meledak. Terapkan teknik re...
# 45  darah tinggi   Badanku terasa lemas. Pastikan untuk mendapat...
# 46  darah tinggi   Setelah stres berkepanjangan. Identifikasi su...
# 47  darah tinggi   Emosiku sulit dikendalikan. Terapkan teknik m...
# 48  darah tinggi   Badanku mudah lelah. Lihat pola tidur dan ist...

# %%
def get_random_response(sentiment):
    relevant_response = df_response[df_response['sentimen'] == sentiment]['response']
    if not relevant_response.empty:
        return np.random.choice(relevant_response)
    else:
        return "Maaf, kami belum dapat melakukan rekomendasi kepada anda."

# %%
user_input = input("Masukkan teks untuk diuji sentimennya: ")
prediction_output = predict_sentiment(user_input)
random_response = get_random_response(prediction_output)
print(f"Prediksi Sentimen: {prediction_output}")
print(f"Respons: {random_response}")
# Out:
# Masukkan teks untuk diuji sentimennya: tes
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'response'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-860d4e6fa2ac> in <cell line: 3>()
#       1 user_input = input("Masukkan teks untuk diuji sentimennya: ")
#       2 prediction_output = predict_sentiment(user_input)
# ----> 3 random_response = get_random_response(prediction_output)
#       4 print(f"Prediksi Sentimen: {prediction_output}")
#       5 print(f"Respons: {random_response}")
#
# <ipython-input-179-7bcc06090cf0> in get_random_response(sentiment)
#       1 def get_random_response(sentiment):
# ----> 2     relevant_response = df_response[df_response['sentimen'] == sentiment]['response']
#       3     if not relevant_response.empty:
#       4         return np.random.choice(relevant_response)
#       5     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'response'
